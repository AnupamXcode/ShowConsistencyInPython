# %%
#Print All Elements nums = [3, 7, 2, 9, 12]
nums=[3,7,2,9,12]
for i in nums:
  print(i)
# Out:
# 3
# 7
# 2
# 9
# 12

# %%
# Find Sum of List nums = [4, 6, 2, 8]
nums=[4,6,2,8]
a=0
for i in nums:
  a=a+i
print(a)
# Out:
# 20

# %%
# Filter Even Numbers nums = [3, 6, 9, 2, 8, 1]
nums=[3,6,9,2,8,1]
new=[ ]
a=0
for i in nums:
  if (i%2==0):
    new.append(i)
print(new)
# Out:
# [6, 2, 8]

# %%
# Count Numbers Greater Than 5 ...nums = [1, 7, 3, 10, 5, 8]
nums = [1, 7, 3, 10, 5, 8]
new=[]
count=0
for i in nums:
  if ( i > 5):
    count+=1
print(count)
# Out:
# 3
