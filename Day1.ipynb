# %%
'''Take an integer input and print:

"Positive" if number > 0

"Negative" if number < 0

"Zero" if number == 0'''

a=int(input("Enter a Number :"))
if (a>0):
  print("Positive")
elif (a<0):
  print("Negative")
else : print("Invalid")
# Out:
# Enter a Number :-5
# Negative

# %%
#Take an integer n and calculate the sum from 1 to n.
n=int(input("Enter a Number:"))
total=0
for i in range(1,n+1):
  total +=i
print("The total First",n,"numbers is :",total)
# Out:
# Enter a Number:6
# The total First 6 numbers is : 21

# %%
# Take an integer n and print all even numbers from 1 to n.
n=int(input("Enter a num:"))
total=0
for i in range(1,n):
  if (i%2==0):
    print(i)
# Out:
# Enter a num:10
# 2
# 4
# 6
# 8
