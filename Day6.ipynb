# %%
# Take an integer n and find the sum of its digits.
n = int(input("Enter the Number :"))
total_sum = 0
while n > 0:
    digit = n % 10
    total_sum += digit
    n = n // 10
print(total_sum)
# Out:
# Enter the Number :456
# 15

# %%
# Take an integer n and count how many digits are odd.
n=int(input("Enter the number:"))
count=0
for i in range(1,n+1):
  digit=n%10
  n=n//10
  if (digit%2!=0):
    count+=1
print(count)
# Out:
# Enter the number:12345
# 3

# %%
# Take an integer n and reverse it.
n=int(input("Enter a number:"))
rev=0
a=n
while n>0:
  digit=n%10
  rev=rev*10+digit
  n=n//10
print(rev)
# Out:
# Enter a number:321
# 123

# %%
'''
*
**
***
****
'''
n = int(input("enter a number: "))
for i in range(1, n + 1):
    print("* " * i)
# Out:
# enter a number: 5
# *
# * *
# * * *
# * * * *
# * * * * *
